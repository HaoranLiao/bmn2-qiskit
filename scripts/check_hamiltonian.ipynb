# %%
import numpy as np
from scipy.sparse import diags
from scipy.sparse import identity
from scipy.sparse import kron
from tqdm import tqdm

from qiskit.quantum_info import Pauli

# %%
def build_operators(L: int, N: int) -> list:
    """Generate all the annihilation operators needed to build the hamiltonian

    Args:
        L (int): the cutoff of the single site Fock space
        N (int): the number of colors of gauge group SU(N)

    Returns:
        list: a list of annihilation operators, length=N_bos
    """
    # The annihilation operator for the single boson
    a_b = diags(np.sqrt(np.linspace(1, L - 1, L - 1)), offsets=1)
    # The identity operator of the Fock space of a single boson
    i_b = identity(L)
    # Bosonic Hilbert space
    N_bos = int(2 * (N ** 2 - 1))  # number of boson sites -> fixed for mini-BMN 2
    product_list = [i_b] * N_bos  # only the identity for bosons repeated N_bos times
    a_b_list = []  # this will contain a1...a6
    for i in np.arange(0, N_bos):  # loop over all bosonic operators
        operator_list = product_list.copy()  # all elements are the identity operator
        operator_list[
            i
        ] = a_b  # the i^th element is now the annihilation operator for a single boson
        a_b_list.append(
            operator_list[0]
        )  # start taking tensor products from first element
        for a in operator_list[1:]:
            a_b_list[i] = kron(
                a_b_list[i], a
            )  # do the outer product between each operator_list element
    return a_b_list


# %%
def build_gauge_casimir(L: int, N: int):
    """Generate the gauge generators operators

    Args:
        L (int): the single site cutoff of the Fock space
        N (int): the number of colors in the gauge group SU(N)

    Returns:
        scipy.sparse : The sparse matrix for \sum_i G_i^2
    """
    # generate the annihilation operators
    bosons = build_operators(L, N)
    # define the generator list for SU(2)
    g_list = [0] * 3
    g_list[0] = 1j * (
        bosons[1].conjugate().transpose() * bosons[2]
        - bosons[2].conjugate().transpose() * bosons[1]
        + bosons[4].conjugate().transpose() * bosons[5]
        - bosons[5].conjugate().transpose() * bosons[4]
    )
    g_list[1] = 1j * (
        bosons[2].conjugate().transpose() * bosons[0]
        - bosons[0].conjugate().transpose() * bosons[2]
        + bosons[5].conjugate().transpose() * bosons[3]
        - bosons[3].conjugate().transpose() * bosons[5]
    )
    g_list[2] = 1j * (
        bosons[0].conjugate().transpose() * bosons[1]
        - bosons[1].conjugate().transpose() * bosons[0]
        + bosons[3].conjugate().transpose() * bosons[4]
        - bosons[4].conjugate().transpose() * bosons[3]
    )

    return g_list[0] * g_list[0] + g_list[1] * g_list[1] + g_list[2] * g_list[2]


# %%
def bmn2_hamiltonian(L: int = 2, N: int = 2, g2N: float = 0.2):
    """Construct the Hamiltonian of the bosonic BMN model as a sparse matrix.
    The cutoff for each boson is L while the 't Hooft coupling in g2N for a gauge group SU(N).
    The limited number of qubits only let us simulate N=2 and L=4 => for 6 bosons this is a 12 qubits problem.

    Args:
        L (int, optional): The cutoff of the bosonic modes (the annihilation operators will be LxL matrices). Defaults to 2.
        N (int, optional): The number of colors of a SU(N) gauge group. The degrees of freedom of one matrix will be N^2-1. Defaults to 2.
        g2N (float, optional): The 't Hooft coupling. Defaults to 0.2.
    """
    print(
        f"Building bosonic BMN Hamiltonian for SU({N}) with cutoff={L} and coupling={g2N}\n"
    )
    a_b_list = build_operators(L,N)
    N_bos = int(2 * (N ** 2 - 1))  # number of boson sites -> FIXED for mini-BMN 2
    # Build the Hamiltonian
    # Start piece by piece
    x_list = []
    # only use the bosonic operators
    for op in a_b_list:
        x_list.append(1 / np.sqrt(2) * (op.conjugate().transpose() + op))
    # Free Hamiltonian
    H_k = 0
    for a in a_b_list:
        H_k = H_k + a.conjugate().transpose() * a
    # vacuum energy
    H_k = H_k + 0.5 * N_bos * identity(L ** N_bos)
    # Interaction among bosons
    V_b = (
        x_list[2] * x_list[2] * x_list[3] * x_list[3]
        + x_list[2] * x_list[2] * x_list[4] * x_list[4]
        + x_list[1] * x_list[1] * x_list[3] * x_list[3]
        + x_list[1] * x_list[1] * x_list[5] * x_list[5]
        + x_list[0] * x_list[0] * x_list[4] * x_list[4]
        + x_list[0] * x_list[0] * x_list[5] * x_list[5]
        - 2 * x_list[0] * x_list[2] * x_list[3] * x_list[5]
        - 2 * x_list[0] * x_list[1] * x_list[3] * x_list[4]
        - 2 * x_list[1] * x_list[2] * x_list[4] * x_list[5]
    )
    # full hamiltonian
    return H_k + g2N / N * V_b

# %%
mat = bmn2_hamiltonian(L=4, N=2)
# Out:
# Building bosonic BMN Hamiltonian for SU(2) with cutoff=4 and coupling=0.2

# %%
np.trace(mat @ Pauli('IIIIIIIIIIII'))
# Out:
# (54681.6+0j)

# %%
import pickle
with open("./H_12q.pk", "rb") as f: 
    paulis, coeffs = pickle.load(f)

# %%
paulis = [Pauli(x) for x in paulis]

# %%
tmp = 0
for p in tqdm(paulis):
    tmp += 1/2**12 * p.to_matrix() * np.trace(mat @ p)
# Out:
#   1%|          | 10/889 [00:08<12:30,  1.17it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 tmp = 0
#       2 for p in tqdm(paulis):
# ----> 3     tmp += 1/2**12 * p.to_matrix() * np.trace(mat @ p)
#
# KeyboardInterrupt:

# %%
tmp.shape
# Out:
# (4096, 4096)

# %%
diff = mat.toarray() - tmp
diff
# Out:
# array([[-3.00000000e+00+0.j,  0.00000000e+00+0.j,  1.38777878e-17+0.j,
#         ...,  0.00000000e+00+0.j,  0.00000000e+00+0.j,
#          0.00000000e+00+0.j],
#        [ 0.00000000e+00+0.j, -2.00000000e+00+0.j,  0.00000000e+00+0.j,
#         ...,  0.00000000e+00+0.j,  0.00000000e+00+0.j,
#          0.00000000e+00+0.j],
#        [ 1.38777878e-17+0.j,  0.00000000e+00+0.j, -3.00000000e+00+0.j,
#         ...,  0.00000000e+00+0.j,  0.00000000e+00+0.j,
#          0.00000000e+00+0.j],
#        ...,
#        [ 0.00000000e+00+0.j,  0.00000000e+00+0.j,  0.00000000e+00+0.j,
#         ...,  3.00000000e+00+0.j,  0.00000000e+00+0.j,
#          1.66533454e-16+0.j],
#        [ 0.00000000e+00+0.j,  0.00000000e+00+0.j,  0.00000000e+00+0.j,
#         ...,  0.00000000e+00+0.j,  2.00000000e+00+0.j,
#          0.00000000e+00+0.j],
#        [ 0.00000000e+00+0.j,  0.00000000e+00+0.j,  0.00000000e+00+0.j,
#         ...,  1.66533454e-16+0.j,  0.00000000e+00+0.j,
#          3.00000000e+00+0.j]])

# %%
out = []
for i in tqdm(range(diff.shape[0])):
    for j in range(diff.shape[0]):
        if np.isclose(diff[i, j], 0):
            diff[i, j] = 0
        else:
            out.append((i, j, diff[i, j]))
out
# Out:
# 100%|██████████| 4096/4096 [02:19<00:00, 29.32it/s]
# [(0, 0, (-3.000000000000004+0j)),
#  (1, 1, (-2.0000000000000018+0j)),
#  (2, 2, (-3+0j)),
#  (3, 3, (-2.0000000000000018+0j)),
#  (4, 4, (-2.0000000000000018+0j)),
#  (5, 5, (-1+0j)),
#  (6, 6, (-1.9999999999999973+0j)),
#  (7, 7, (-1+0j)),
#  (8, 8, (-3+0j)),
#  (9, 9, (-1.9999999999999973+0j)),
#  (10, 10, (-2.9999999999999947+0j)),
#  (11, 11, (-1.9999999999999982+0j)),
#  (12, 12, (-2.0000000000000018+0j)),
#  (13, 13, (-1+0j)),
#  (14, 14, (-1.9999999999999982+0j)),
#  (15, 15, (-1+0j)),
#  (16, 16, (-2.0000000000000018+0j)),
#  (17, 17, (-1+0j)),
#  (18, 18, (-1.9999999999999973+0j)),
#  (19, 19, (-1+0j)),
#  (20, 20, (-1+0j)),
#  (22, 22, (-0.9999999999999956+0j)),
#  (24, 24, (-1.9999999999999973+0j)),
#  (25, 25, (-0.9999999999999956+0j)),
#  (26, 26, (-1.999999999999993+0j)),
#  (27, 27, (-0.9999999999999947+0j)),
#  (28, 28, (-1+0j)),
#  (30, 30, (-0.9999999999999947+0j)),
#  (32, 32, (-3+0j)),
#  (33, 33, (-1.9999999999999973+0j)),
#  (34, 34, (-2.9999999999999947+0j)),
#  (35, 35, (-1.9999999999999982+0j)),
#  (36, 36, (-1.9999999999999973+0j)),
#  (37, 37, (-0.9999999999999956+0j)),
#  (38, 38, (-1.999999999999993+0j)),
#  (39, 39, (-0.9999999999999947+0j)),
#  (40, 40, (-2.9999999999999947+0j)),
#  (41, 41, (-1.999999999999993+0j)),
#  (42, 42, (-2.9999999999999893+0j)),
#  (43, 43, (-1.999999999999993+0j)),
#  (44, 44, (-1.9999999999999982+0j)),
#  (45, 45, (-0.9999999999999947+0j)),
#  (46, 46, (-1.999999999999993+0j)),
#  (47, 47, (-0.9999999999999947+0j)),
#  (48, 48, (-2.0000000000000018+0j)),
#  (49, 49, (-1+0j)),
#  (50, 50, (-1.9999999999999982+0j)),
#  (51, 51, (-1+0j)),
#  (52, 52, (-1+0j)),
#  (54, 54, (-0.9999999999999947+0j)),
#  (56, 56, (-1.9999999999999982+0j)),
#  (57, 57, (-0.9999999999999947+0j)),
#  (58, 58, (-1.999999999999993+0j)),
#  (59, 59, (-0.9999999999999947+0j)),
#  (60, 60, (-1+0j)),
#  (62, 62, (-0.9999999999999947+0j)),
#  (64, 64, (-2.0000000000000018+0j)),
#  (65, 65, (-1+0j)),
#  (66, 66, (-1.9999999999999973+0j)),
#  (67, 67, (-1+0j)),
#  (68, 68, (-1.0000000000000009+0j)),
#  (70, 70, (-0.9999999999999964+0j)),
#  (72, 72, (-2+0j)),
#  (73, 73, (-0.9999999999999982+0j)),
#  (74, 74, (-1.9999999999999964+0j)),
#  (75, 75, (-0.9999999999999982+0j)),
#  (76, 76, (-1.0000000000000009+0j)),
#  (78, 78, (-0.9999999999999964+0j)),
#  (80, 80, (-1.0000000000000009+0j)),
#  (82, 82, (-0.9999999999999964+0j)),
#  (85, 85, (1.0000000000000018+0j)),
#  (87, 87, (1.0000000000000018+0j)),
#  (88, 88, (-1+0j)),
#  (90, 90, (-0.9999999999999947+0j)),
#  (93, 93, (1.0000000000000018+0j)),
#  (95, 95, (1.0000000000000018+0j)),
#  (96, 96, (-2+0j)),
#  (97, 97, (-0.9999999999999982+0j)),
#  (98, 98, (-1.9999999999999964+0j)),
#  (610, 610, (-2.0000000000000018+0j)),
#  (611, 611, (-1.0000000000000018+0j)),
#  (612, 612, (-1.0000000000000018+0j)),
#  (614, 614, (-1+0j)),
#  (616, 616, (-1.9999999999999982+0j)),
#  (617, 617, (-0.9999999999999982+0j)),
#  (618, 618, (-1.9999999999999982+0j)),
#  (619, 619, (-0.9999999999999982+0j)),
#  (620, 620, (-1.0000000000000018+0j)),
#  (622, 622, (-0.9999999999999964+0j)),
#  (624, 624, (-1+0j)),
#  (626, 626, (-1.0000000000000018+0j)),
#  (629, 629, (1+0j)),
#  (631, 631, (1+0j)),
#  (632, 632, (-0.9999999999999982+0j)),
#  (634, 634, (-1+0j)),
#  (637, 637, (1+0j)),
#  (639, 639, (1.0000000000000018+0j)),
#  (640, 640, (-2.9999999999999947+0j)),
#  (641, 641, (-1.9999999999999964+0j)),
#  (642, 642, (-2.9999999999999947+0j)),
#  (643, 643, (-1.9999999999999964+0j)),
#  (644, 644, (-1.9999999999999964+0j)),
#  (645, 645, (-0.9999999999999964+0j)),
#  (646, 646, (-1.9999999999999947+0j)),
#  (647, 647, (-0.9999999999999964+0j)),
#  (648, 648, (-2.9999999999999947+0j)),
#  (649, 649, (-1.9999999999999947+0j)),
#  (650, 650, (-2.9999999999999964+0j)),
#  (651, 651, (-1.9999999999999947+0j)),
#  (652, 652, (-1.9999999999999964+0j)),
#  (653, 653, (-0.9999999999999964+0j)),
#  (654, 654, (-1.9999999999999982+0j)),
#  (655, 655, (-0.9999999999999964+0j)),
#  (656, 656, (-1.9999999999999982+0j)),
#  (657, 657, (-1+0j)),
#  (658, 658, (-1.9999999999999982+0j)),
#  (659, 659, (-1+0j)),
#  (660, 660, (-1+0j)),
#  (662, 662, (-0.9999999999999982+0j)),
#  (664, 664, (-1.9999999999999982+0j)),
#  (665, 665, (-0.9999999999999982+0j)),
#  (666, 666, (-1.9999999999999982+0j)),
#  (667, 667, (-0.9999999999999982+0j)),
#  (668, 668, (-1+0j)),
#  (670, 670, (-1.0000000000000018+0j)),
#  (672, 672, (-3+0j)),
#  (673, 673, (-2.0000000000000018+0j)),
#  (674, 674, (-2.9999999999999893+0j)),
#  (675, 675, (-2.0000000000000018+0j)),
#  (676, 676, (-2.0000000000000018+0j)),
#  (677, 677, (-1.0000000000000018+0j)),
#  (678, 678, (-1.9999999999999858+0j)),
#  (679, 679, (-0.9999999999999893+0j)),
#  (680, 680, (-2.9999999999999893+0j)),
#  (681, 681, (-1.9999999999999858+0j)),
#  (682, 682, (-2.999999999999984+0j)),
#  (683, 683, (-1.9999999999999858+0j)),
#  (684, 684, (-2.0000000000000036+0j)),
#  (685, 685, (-0.9999999999999929+0j)),
#  (686, 686, (-1.9999999999999858+0j)),
#  (687, 687, (-0.9999999999999893+0j)),
#  (688, 688, (-1.9999999999999982+0j)),
#  (689, 689, (-1+0j)),
#  (690, 690, (-2+0j)),
#  (691, 691, (-1+0j)),
#  (692, 692, (-1+0j)),
#  (694, 694, (-1.0000000000000018+0j)),
#  (696, 696, (-1.9999999999999982+0j)),
#  (697, 697, (-1+0j)),
#  (698, 698, (-1.9999999999999964+0j)),
#  (699, 699, (-1+0j)),
#  (700, 700, (-1.0000000000000018+0j)),
#  (702, 702, (-1+0j)),
#  (704, 704, (-1.9999999999999982+0j)),
#  (705, 705, (-0.9999999999999982+0j)),
#  (706, 706, (-1.9999999999999982+0j)),
#  (707, 707, (-0.9999999999999982+0j)),
#  (708, 708, (-0.9999999999999964+0j)),
#  (710, 710, (-0.9999999999999982+0j)),
#  (712, 712, (-1.9999999999999964+0j)),
#  (713, 713, (-0.9999999999999964+0j)),
#  (714, 714, (-1.9999999999999982+0j)),
#  (715, 715, (-0.9999999999999964+0j)),
#  (716, 716, (-0.9999999999999964+0j)),
#  (718, 718, (-0.9999999999999982+0j)),
#  (720, 720, (-1+0j)),
#  (722, 722, (-1.0000000000000018+0j)),
#  (725, 725, (1+0j)),
#  (727, 727, (1+0j)),
#  (728, 728, (-0.9999999999999982+0j)),
#  (730, 730, (-1+0j)),
#  (733, 733, (1+0j)),
#  (735, 735, (1.0000000000000018+0j)),
#  (736, 736, (-2.0000000000000018+0j)),
#  (737, 737, (-1.0000000000000018+0j)),
#  (738, 738, (-2.0000000000000036+0j)),
#  (739, 739, (-1.0000000000000018+0j)),
#  (740, 740, (-1.0000000000000018+0j)),
#  (742, 742, (-0.9999999999999964+0j)),
#  (744, 744, (-1.9999999999999982+0j)),
#  (745, 745, (-1+0j)),
#  (746, 746, (-1.9999999999999964+0j)),
#  (747, 747, (-1+0j)),
#  (748, 748, (-1.0000000000000036+0j)),
#  (750, 750, (-0.9999999999999929+0j)),
#  (752, 752, (-1+0j)),
#  (754, 754, (-1.0000000000000018+0j)),
#  (757, 757, (1+0j)),
#  (759, 759, (1.0000000000000018+0j)),
#  (760, 760, (-0.9999999999999964+0j)),
#  (762, 762, (-1+0j)),
#  (765, 765, (1+0j)),
#  (767, 767, (1+0j)),
#  (768, 768, (-2.0000000000000018+0j)),
#  (769, 769, (-1.0000000000000009+0j)),
#  (770, 770, (-2+0j)),
#  (771, 771, (-1.0000000000000018+0j)),
#  (772, 772, (-1+0j)),
#  (774, 774, (-0.9999999999999982+0j)),
#  (776, 776, (-1.9999999999999982+0j)),
#  (777, 777, (-0.9999999999999964+0j)),
#  (778, 778, (-1.9999999999999964+0j)),
#  (779, 779, (-0.9999999999999964+0j)),
#  (780, 780, (-1+0j)),
#  (782, 782, (-0.9999999999999982+0j)),
#  (784, 784, (-1.0000000000000009+0j)),
#  (786, 786, (-1+0j)),
#  (789, 789, (1.0000000000000018+0j)),
#  (791, 791, (1.0000000000000018+0j)),
#  (792, 792, (-0.9999999999999964+0j)),
#  (794, 794, (-0.9999999999999947+0j)),
#  (797, 797, (1.0000000000000018+0j)),
#  (799, 799, (1+0j)),
#  (800, 800, (-2+0j)),
#  (801, 801, (-1+0j)),
#  (802, 802, (-2+0j)),
#  (803, 803, (-1+0j)),
#  (804, 804, (-0.9999999999999982+0j)),
#  (920, 920, (-1.0000000000000018+0j)),
#  (922, 922, (-1+0j)),
#  (925, 925, (1+0j)),
#  (927, 927, (1.0000000000000018+0j)),
#  (928, 928, (-2.0000000000000018+0j)),
#  (929, 929, (-1.0000000000000018+0j)),
#  (930, 930, (-2+0j)),
#  (931, 931, (-1.0000000000000018+0j)),
#  (932, 932, (-1.0000000000000018+0j)),
#  (934, 934, (-1.0000000000000018+0j)),
#  (936, 936, (-2.0000000000000018+0j)),
#  (937, 937, (-0.9999999999999964+0j)),
#  (938, 938, (-1.9999999999999964+0j)),
#  (939, 939, (-0.9999999999999929+0j)),
#  (940, 940, (-1.0000000000000036+0j)),
#  (942, 942, (-1+0j)),
#  (944, 944, (-1+0j)),
#  (946, 946, (-0.9999999999999982+0j)),
#  (949, 949, (1+0j)),
#  (951, 951, (1.0000000000000018+0j)),
#  (952, 952, (-1+0j)),
#  (954, 954, (-1+0j)),
#  (957, 957, (1+0j)),
#  (959, 959, (1+0j)),
#  (960, 960, (-1+0j)),
#  (962, 962, (-0.9999999999999982+0j)),
#  (965, 965, (1.0000000000000018+0j)),
#  (967, 967, (1+0j)),
#  (968, 968, (-0.9999999999999982+0j)),
#  (970, 970, (-0.9999999999999964+0j)),
#  (973, 973, (1+0j)),
#  (975, 975, (1+0j)),
#  (977, 977, (1+0j)),
#  (979, 979, (0.9999999999999982+0j)),
#  (980, 980, (1+0j)),
#  (981, 981, (2.0000000000000018+0j)),
#  (982, 982, (1.0000000000000018+0j)),
#  (983, 983, (1.9999999999999982+0j)),
#  (985, 985, (1.0000000000000018+0j)),
#  (987, 987, (1.0000000000000018+0j)),
#  (988, 988, (0.9999999999999982+0j)),
#  (989, 989, (1.9999999999999982+0j)),
#  (990, 990, (0.9999999999999982+0j)),
#  (991, 991, (1.9999999999999982+0j)),
#  (992, 992, (-1.0000000000000018+0j)),
#  (994, 994, (-1+0j)),
#  (997, 997, (1+0j)),
#  (999, 999, (1.0000000000000018+0j)),
#  (1000, 1000, (-0.9999999999999982+0j)),
#  (1002, 1002, (-1.000000000000007+0j)),
#  (1005, 1005, (1+0j)),
#  (1007, 1007, (1+0j)),
#  (1009, 1009, (0.9999999999999982+0j)),
#  (1011, 1011, (0.9999999999999982+0j)),
#  (1012, 1012, (0.9999999999999982+0j)),
#  (1013, 1013, (1.9999999999999982+0j)),
#  (1014, 1014, (0.9999999999999982+0j)),
#  (1015, 1015, (1.9999999999999982+0j)),
#  (1017, 1017, (1+0j)),
#  (1019, 1019, (0.9999999999999964+0j)),
#  (1020, 1020, (0.9999999999999964+0j)),
#  (1021, 1021, (1.9999999999999964+0j)),
#  (1022, 1022, (0.9999999999999964+0j)),
#  (1023, 1023, (2+0j)),
#  (1024, 1024, (-2.0000000000000018+0j)),
#  (1025, 1025, (-1.0000000000000009+0j)),
#  (1026, 1026, (-2+0j)),
#  (1027, 1027, (-1.0000000000000009+0j)),
#  (1028, 1028, (-1.0000000000000009+0j)),
#  (1030, 1030, (-1+0j)),
#  (1032, 1032, (-2+0j)),
#  (1438, 1438, (0.9999999999999982+0j)),
#  (1439, 1439, (2+0j)),
#  (1440, 1440, (-1+0j)),
#  (1442, 1442, (-1.0000000000000018+0j)),
#  (1445, 1445, (0.9999999999999982+0j)),
#  (1447, 1447, (0.9999999999999982+0j)),
#  (1448, 1448, (-1.0000000000000036+0j)),
#  (1450, 1450, (-0.9999999999999893+0j)),
#  (1453, 1453, (0.9999999999999982+0j)),
#  (1455, 1455, (1.0000000000000036+0j)),
#  (1457, 1457, (1.0000000000000018+0j)),
#  (1459, 1459, (1.0000000000000018+0j)),
#  (1460, 1460, (1+0j)),
#  (1461, 1461, (2+0j)),
#  (1462, 1462, (0.9999999999999982+0j)),
#  (1463, 1463, (2+0j)),
#  (1465, 1465, (0.9999999999999982+0j)),
#  (1467, 1467, (1.0000000000000036+0j)),
#  (1468, 1468, (1+0j)),
#  (1469, 1469, (2+0j)),
#  (1470, 1470, (0.9999999999999982+0j)),
#  (1471, 1471, (1.9999999999999982+0j)),
#  ...]

# %%
for i, j, val in out:
    if i != j:
        print((i, j, val))

# %%
import pickle
with open("./H_12q.pk", "rb") as f: 
    paulis, coeffs = pickle.load(f)

# %%
import itertools

def generate_all_strings(size=12, existing_paulis=None):
    letters = ['Z', 'I']
    excluded = set(existing_paulis) if existing_paulis else set()
    
    result = []
    for p in tqdm(itertools.product(letters, repeat=size)):
        candidate = ''.join(p)
        if candidate not in excluded:
            result.append(candidate)
    
    return result

all_other_z_paulis = generate_all_strings(existing_paulis=paulis)
all_other_z_paulis
# Out:
# 4096it [00:00, 1370224.05it/s]
# ['ZZZZZZZZZZZZ',
#  'ZZZZZZZZZZZI',
#  'ZZZZZZZZZZIZ',
#  'ZZZZZZZZZZII',
#  'ZZZZZZZZZIZZ',
#  'ZZZZZZZZZIZI',
#  'ZZZZZZZZZIIZ',
#  'ZZZZZZZZZIII',
#  'ZZZZZZZZIZZZ',
#  'ZZZZZZZZIZZI',
#  'ZZZZZZZZIZIZ',
#  'ZZZZZZZZIZII',
#  'ZZZZZZZZIIZZ',
#  'ZZZZZZZZIIZI',
#  'ZZZZZZZZIIIZ',
#  'ZZZZZZZZIIII',
#  'ZZZZZZZIZZZZ',
#  'ZZZZZZZIZZZI',
#  'ZZZZZZZIZZIZ',
#  'ZZZZZZZIZZII',
#  'ZZZZZZZIZIZZ',
#  'ZZZZZZZIZIZI',
#  'ZZZZZZZIZIIZ',
#  'ZZZZZZZIZIII',
#  'ZZZZZZZIIZZZ',
#  'ZZZZZZZIIZZI',
#  'ZZZZZZZIIZIZ',
#  'ZZZZZZZIIZII',
#  'ZZZZZZZIIIZZ',
#  'ZZZZZZZIIIZI',
#  'ZZZZZZZIIIIZ',
#  'ZZZZZZZIIIII',
#  'ZZZZZZIZZZZZ',
#  'ZZZZZZIZZZZI',
#  'ZZZZZZIZZZIZ',
#  'ZZZZZZIZZZII',
#  'ZZZZZZIZZIZZ',
#  'ZZZZZZIZZIZI',
#  'ZZZZZZIZZIIZ',
#  'ZZZZZZIZZIII',
#  'ZZZZZZIZIZZZ',
#  'ZZZZZZIZIZZI',
#  'ZZZZZZIZIZIZ',
#  'ZZZZZZIZIZII',
#  'ZZZZZZIZIIZZ',
#  'ZZZZZZIZIIZI',
#  'ZZZZZZIZIIIZ',
#  'ZZZZZZIZIIII',
#  'ZZZZZZIIZZZZ',
#  'ZZZZZZIIZZZI',
#  'ZZZZZZIIZZIZ',
#  'ZZZZZZIIZZII',
#  'ZZZZZZIIZIZZ',
#  'ZZZZZZIIZIZI',
#  'ZZZZZZIIZIIZ',
#  'ZZZZZZIIZIII',
#  'ZZZZZZIIIZZZ',
#  'ZZZZZZIIIZZI',
#  'ZZZZZZIIIZIZ',
#  'ZZZZZZIIIZII',
#  'ZZZZZZIIIIZZ',
#  'ZZZZZZIIIIZI',
#  'ZZZZZZIIIIIZ',
#  'ZZZZZZIIIIII',
#  'ZZZZZIZZZZZZ',
#  'ZZZZZIZZZZZI',
#  'ZZZZZIZZZZIZ',
#  'ZZZZZIZZZZII',
#  'ZZZZZIZZZIZZ',
#  'ZZZZZIZZZIZI',
#  'ZZZZZIZZZIIZ',
#  'ZZZZZIZZZIII',
#  'ZZZZZIZZIZZZ',
#  'ZZZZZIZZIZZI',
#  'ZZZZZIZZIZIZ',
#  'ZZZZZIZZIZII',
#  'ZZZZZIZZIIZZ',
#  'ZZZZZIZZIIZI',
#  'ZZZZZIZZIIIZ',
#  'ZZZZZIZZIIII',
#  'ZZZZZIZIZZZZ',
#  'ZZZZZIZIZZZI',
#  'ZZZZZIZIZZIZ',
#  'ZZZZZIZIZZII',
#  'ZZZZZIZIZIZZ',
#  'ZZZZZIZIZIZI',
#  'ZZZZZIZIZIIZ',
#  'ZZZZZIZIZIII',
#  'ZZZZZIZIIZZZ',
#  'ZZZZZIZIIZZI',
#  'ZZZZZIZIIZIZ',
#  'ZZZZZIZIIZII',
#  'ZZZZZIZIIIZZ',
#  'ZZZZZIZIIIZI',
#  'ZZZZZIZIIIIZ',
#  'ZZZZZIZIIIII',
#  'ZZZZZIIZZZZZ',
#  'ZZZZZIIZZZZI',
#  'ZZZZZIIZZZIZ',
#  'ZZZZZIIZZZII',
#  'ZZZZZIIZZIZZ',
#  'ZZZZZIIZZIZI',
#  'ZZZZZIIZZIIZ',
#  'ZZZZZIIZZIII',
#  'ZZZZZIIZIZZZ',
#  'ZZZZZIIZIZZI',
#  'ZZZZZIIZIZIZ',
#  'ZZZZZIIZIZII',
#  'ZZZZZIIZIIZZ',
#  'ZZZZZIIZIIZI',
#  'ZZZZZIIZIIIZ',
#  'ZZZZZIIZIIII',
#  'ZZZZZIIIZZZZ',
#  'ZZZZZIIIZZZI',
#  'ZZZZZIIIZZIZ',
#  'ZZZZZIIIZZII',
#  'ZZZZZIIIZIZZ',
#  'ZZZZZIIIZIZI',
#  'ZZZZZIIIZIIZ',
#  'ZZZZZIIIZIII',
#  'ZZZZZIIIIZZZ',
#  'ZZZZZIIIIZZI',
#  'ZZZZZIIIIZIZ',
#  'ZZZZZIIIIZII',
#  'ZZZZZIIIIIZZ',
#  'ZZZZZIIIIIZI',
#  'ZZZZZIIIIIIZ',
#  'ZZZZZIIIIIII',
#  'ZZZZIZZZZZZZ',
#  'ZZZZIZZZZZZI',
#  'ZZZZIZZZZZIZ',
#  'ZZZZIZZZZZII',
#  'ZZZZIZZZZIZZ',
#  'ZZZZIZZZZIZI',
#  'ZZZZIZZZZIIZ',
#  'ZZZZIZZZZIII',
#  'ZZZZIZZZIZZZ',
#  'ZZZZIZZZIZZI',
#  'ZZZZIZZZIZIZ',
#  'ZZZZIZZZIZII',
#  'ZZZZIZZZIIZZ',
#  'ZZZZIZZZIIZI',
#  'ZZZZIZZZIIIZ',
#  'ZZZZIZZZIIII',
#  'ZZZZIZZIZZZZ',
#  'ZZZZIZZIZZZI',
#  'ZZZZIZZIZZIZ',
#  'ZZZZIZZIZZII',
#  'ZZZZIZZIZIZZ',
#  'ZZZZIZZIZIZI',
#  'ZZZZIZZIZIIZ',
#  'ZZZZIZZIZIII',
#  'ZZZZIZZIIZZZ',
#  'ZZZZIZZIIZZI',
#  'ZZZZIZZIIZIZ',
#  'ZZZZIZZIIZII',
#  'ZZZZIZZIIIZZ',
#  'ZZZZIZZIIIZI',
#  'ZZZZIZZIIIIZ',
#  'ZZZZIZZIIIII',
#  'ZZZZIZIZZZZZ',
#  'ZZZZIZIZZZZI',
#  'ZZZZIZIZZZIZ',
#  'ZZZZIZIZZZII',
#  'ZZZZIZIZZIZZ',
#  'ZZZZIZIZZIZI',
#  'ZZZZIZIZZIIZ',
#  'ZZZZIZIZZIII',
#  'ZZZZIZIZIZZZ',
#  'ZZZZIZIZIZZI',
#  'ZZZZIZIZIZIZ',
#  'ZZZZIZIZIZII',
#  'ZZZZIZIZIIZZ',
#  'ZZZZIZIZIIZI',
#  'ZZZZIZIZIIIZ',
#  'ZZZZIZIZIIII',
#  'ZZZZIZIIZZZZ',
#  'ZZZZIZIIZZZI',
#  'ZZZZIZIIZZIZ',
#  'ZZZZIZIIZZII',
#  'ZZZZIZIIZIZZ',
#  'ZZZZIZIIZIZI',
#  'ZZZZIZIIZIIZ',
#  'ZZZZIZIIZIII',
#  'ZZZZIZIIIZZZ',
#  'ZZZZIZIIIZZI',
#  'ZZZZIZIIIZIZ',
#  'ZZZZIZIIIZII',
#  'ZZZZIZIIIIZZ',
#  'ZZZZIZIIIIZI',
#  'ZZZZIZIIIIIZ',
#  'ZZZZIZIIIIII',
#  'ZZZZIIZZZZZZ',
#  'ZZZZIIZZZZZI',
#  'ZZZZIIZZZZIZ',
#  'ZZZZIIZZZZII',
#  'ZZZZIIZZZIZZ',
#  'ZZZZIIZZZIZI',
#  'ZZZZIIZZZIIZ',
#  'ZZZZIIZZZIII',
#  'ZZZZIIZZIZZZ',
#  'ZZZZIIZZIZZI',
#  'ZZZZIIZZIZIZ',
#  'ZZZZIIZZIZII',
#  'ZZZZIIZZIIZZ',
#  'ZZZZIIZZIIZI',
#  'ZZZZIIZZIIIZ',
#  'ZZZZIIZZIIII',
#  'ZZZZIIZIZZZZ',
#  'ZZZZIIZIZZZI',
#  'ZZZZIIZIZZIZ',
#  'ZZZZIIZIZZII',
#  'ZZZZIIZIZIZZ',
#  'ZZZZIIZIZIZI',
#  'ZZZZIIZIZIIZ',
#  'ZZZZIIZIZIII',
#  'ZZZZIIZIIZZZ',
#  'ZZZZIIZIIZZI',
#  'ZZZZIIZIIZIZ',
#  'ZZZZIIZIIZII',
#  'ZZZZIIZIIIZZ',
#  'ZZZZIIZIIIZI',
#  'ZZZZIIZIIIIZ',
#  'ZZZZIIZIIIII',
#  'ZZZZIIIZZZZZ',
#  'ZZZZIIIZZZZI',
#  'ZZZZIIIZZZIZ',
#  'ZZZZIIIZZZII',
#  'ZZZZIIIZZIZZ',
#  'ZZZZIIIZZIZI',
#  'ZZZZIIIZZIIZ',
#  'ZZZZIIIZZIII',
#  'ZZZZIIIZIZZZ',
#  'ZZZZIIIZIZZI',
#  'ZZZZIIIZIZIZ',
#  'ZZZZIIIZIZII',
#  'ZZZZIIIZIIZZ',
#  'ZZZZIIIZIIZI',
#  'ZZZZIIIZIIIZ',
#  'ZZZZIIIZIIII',
#  'ZZZZIIIIZZZZ',
#  'ZZZZIIIIZZZI',
#  'ZZZZIIIIZZIZ',
#  'ZZZZIIIIZZII',
#  'ZZZZIIIIZIZZ',
#  'ZZZZIIIIZIZI',
#  'ZZZZIIIIZIIZ',
#  'ZZZZIIIIZIII',
#  'ZZZZIIIIIZZZ',
#  'ZZZZIIIIIZZI',
#  'ZZZZIIIIIZIZ',
#  'ZZZZIIIIIZII',
#  'ZZZZIIIIIIZZ',
#  'ZZZZIIIIIIZI',
#  'ZZZZIIIIIIIZ',
#  'ZZZZIIIIIIII',
#  'ZZZIZZZZZZZZ',
#  'ZZZIZZZZZZZI',
#  'ZZZIZZZZZZIZ',
#  'ZZZIZZZZZZII',
#  'ZZZIZZZZZIZZ',
#  'ZZZIZZZZZIZI',
#  'ZZZIZZZZZIIZ',
#  'ZZZIZZZZZIII',
#  'ZZZIZZZZIZZZ',
#  'ZZZIZZZZIZZI',
#  'ZZZIZZZZIZIZ',
#  'ZZZIZZZZIZII',
#  'ZZZIZZZZIIZZ',
#  'ZZZIZZZZIIZI',
#  'ZZZIZZZZIIIZ',
#  'ZZZIZZZZIIII',
#  'ZZZIZZZIZZZZ',
#  'ZZZIZZZIZZZI',
#  'ZZZIZZZIZZIZ',
#  'ZZZIZZZIZZII',
#  'ZZZIZZZIZIZZ',
#  'ZZZIZZZIZIZI',
#  'ZZZIZZZIZIIZ',
#  'ZZZIZZZIZIII',
#  'ZZZIZZZIIZZZ',
#  'ZZZIZZZIIZZI',
#  'ZZZIZZZIIZIZ',
#  'ZZZIZZZIIZII',
#  'ZZZIZZZIIIZZ',
#  'ZZZIZZZIIIZI',
#  'ZZZIZZZIIIIZ',
#  'ZZZIZZZIIIII',
#  'ZZZIZZIZZZZZ',
#  'ZZZIZZIZZZZI',
#  'ZZZIZZIZZZIZ',
#  'ZZZIZZIZZZII',
#  'ZZZIZZIZZIZZ',
#  'ZZZIZZIZZIZI',
#  'ZZZIZZIZZIIZ',
#  'ZZZIZZIZZIII',
#  'ZZZIZZIZIZZZ',
#  'ZZZIZZIZIZZI',
#  'ZZZIZZIZIZIZ',
#  'ZZZIZZIZIZII',
#  'ZZZIZZIZIIZZ',
#  'ZZZIZZIZIIZI',
#  'ZZZIZZIZIIIZ',
#  'ZZZIZZIZIIII',
#  'ZZZIZZIIZZZZ',
#  'ZZZIZZIIZZZI',
#  'ZZZIZZIIZZIZ',
#  'ZZZIZZIIZZII',
#  'ZZZIZZIIZIZZ',
#  'ZZZIZZIIZIZI',
#  'ZZZIZZIIZIIZ',
#  'ZZZIZZIIZIII',
#  'ZZZIZZIIIZZZ',
#  'ZZZIZZIIIZZI',
#  'ZZZIZZIIIZIZ',
#  'ZZZIZZIIIZII',
#  'ZZZIZZIIIIZZ',
#  'ZZZIZZIIIIZI',
#  'ZZZIZZIIIIIZ',
#  'ZZZIZZIIIIII',
#  'ZZZIZIZZZZZZ',
#  'ZZZIZIZZZZZI',
#  'ZZZIZIZZZZIZ',
#  'ZZZIZIZZZZII',
#  'ZZZIZIZZZIZZ',
#  'ZZZIZIZZZIZI',
#  'ZZZIZIZZZIIZ',
#  'ZZZIZIZZZIII',
#  'ZZZIZIZZIZZZ',
#  'ZZZIZIZZIZZI',
#  'ZZZIZIZZIZIZ',
#  'ZZZIZIZZIZII',
#  'ZZZIZIZZIIZZ',
#  'ZZZIZIZZIIZI',
#  'ZZZIZIZZIIIZ',
#  'ZZZIZIZZIIII',
#  'ZZZIZIZIZZZZ',
#  'ZZZIZIZIZZZI',
#  'ZZZIZIZIZZIZ',
#  'ZZZIZIZIZZII',
#  'ZZZIZIZIZIZZ',
#  'ZZZIZIZIZIZI',
#  'ZZZIZIZIZIIZ',
#  'ZZZIZIZIZIII',
#  'ZZZIZIZIIZZZ',
#  'ZZZIZIZIIZZI',
#  'ZZZIZIZIIZIZ',
#  'ZZZIZIZIIZII',
#  'ZZZIZIZIIIZZ',
#  'ZZZIZIZIIIZI',
#  'ZZZIZIZIIIIZ',
#  'ZZZIZIZIIIII',
#  'ZZZIZIIZZZZZ',
#  'ZZZIZIIZZZZI',
#  'ZZZIZIIZZZIZ',
#  'ZZZIZIIZZZII',
#  'ZZZIZIIZZIZZ',
#  'ZZZIZIIZZIZI',
#  'ZZZIZIIZZIIZ',
#  'ZZZIZIIZZIII',
#  'ZZZIZIIZIZZZ',
#  'ZZZIZIIZIZZI',
#  'ZZZIZIIZIZIZ',
#  'ZZZIZIIZIZII',
#  'ZZZIZIIZIIZZ',
#  'ZZZIZIIZIIZI',
#  'ZZZIZIIZIIIZ',
#  'ZZZIZIIZIIII',
#  'ZZZIZIIIZZZZ',
#  'ZZZIZIIIZZZI',
#  'ZZZIZIIIZZIZ',
#  'ZZZIZIIIZZII',
#  'ZZZIZIIIZIZZ',
#  'ZZZIZIIIZIZI',
#  'ZZZIZIIIZIIZ',
#  'ZZZIZIIIZIII',
#  'ZZZIZIIIIZZZ',
#  'ZZZIZIIIIZZI',
#  'ZZZIZIIIIZIZ',
#  'ZZZIZIIIIZII',
#  'ZZZIZIIIIIZZ',
#  'ZZZIZIIIIIZI',
#  'ZZZIZIIIIIIZ',
#  'ZZZIZIIIIIII',
#  'ZZZIIZZZZZZZ',
#  'ZZZIIZZZZZZI',
#  'ZZZIIZZZZZIZ',
#  'ZZZIIZZZZZII',
#  'ZZZIIZZZZIZZ',
#  'ZZZIIZZZZIZI',
#  'ZZZIIZZZZIIZ',
#  'ZZZIIZZZZIII',
#  'ZZZIIZZZIZZZ',
#  'ZZZIIZZZIZZI',
#  'ZZZIIZZZIZIZ',
#  'ZZZIIZZZIZII',
#  'ZZZIIZZZIIZZ',
#  'ZZZIIZZZIIZI',
#  'ZZZIIZZZIIIZ',
#  'ZZZIIZZZIIII',
#  'ZZZIIZZIZZZZ',
#  'ZZZIIZZIZZZI',
#  'ZZZIIZZIZZIZ',
#  'ZZZIIZZIZZII',
#  'ZZZIIZZIZIZZ',
#  'ZZZIIZZIZIZI',
#  'ZZZIIZZIZIIZ',
#  'ZZZIIZZIZIII',
#  'ZZZIIZZIIZZZ',
#  'ZZZIIZZIIZZI',
#  'ZZZIIZZIIZIZ',
#  'ZZZIIZZIIZII',
#  'ZZZIIZZIIIZZ',
#  'ZZZIIZZIIIZI',
#  'ZZZIIZZIIIIZ',
#  'ZZZIIZZIIIII',
#  'ZZZIIZIZZZZZ',
#  'ZZZIIZIZZZZI',
#  'ZZZIIZIZZZIZ',
#  'ZZZIIZIZZZII',
#  'ZZZIIZIZZIZZ',
#  'ZZZIIZIZZIZI',
#  'ZZZIIZIZZIIZ',
#  'ZZZIIZIZZIII',
#  'ZZZIIZIZIZZZ',
#  'ZZZIIZIZIZZI',
#  'ZZZIIZIZIZIZ',
#  'ZZZIIZIZIZII',
#  'ZZZIIZIZIIZZ',
#  'ZZZIIZIZIIZI',
#  'ZZZIIZIZIIIZ',
#  'ZZZIIZIZIIII',
#  'ZZZIIZIIZZZZ',
#  'ZZZIIZIIZZZI',
#  'ZZZIIZIIZZIZ',
#  'ZZZIIZIIZZII',
#  'ZZZIIZIIZIZZ',
#  'ZZZIIZIIZIZI',
#  'ZZZIIZIIZIIZ',
#  'ZZZIIZIIZIII',
#  'ZZZIIZIIIZZZ',
#  'ZZZIIZIIIZZI',
#  'ZZZIIZIIIZIZ',
#  'ZZZIIZIIIZII',
#  'ZZZIIZIIIIZZ',
#  'ZZZIIZIIIIZI',
#  'ZZZIIZIIIIIZ',
#  'ZZZIIZIIIIII',
#  'ZZZIIIZZZZZZ',
#  'ZZZIIIZZZZZI',
#  'ZZZIIIZZZZIZ',
#  'ZZZIIIZZZZII',
#  'ZZZIIIZZZIZZ',
#  'ZZZIIIZZZIZI',
#  'ZZZIIIZZZIIZ',
#  'ZZZIIIZZZIII',
#  'ZZZIIIZZIZZZ',
#  'ZZZIIIZZIZZI',
#  'ZZZIIIZZIZIZ',
#  'ZZZIIIZZIZII',
#  'ZZZIIIZZIIZZ',
#  'ZZZIIIZZIIZI',
#  'ZZZIIIZZIIIZ',
#  'ZZZIIIZZIIII',
#  'ZZZIIIZIZZZZ',
#  'ZZZIIIZIZZZI',
#  'ZZZIIIZIZZIZ',
#  'ZZZIIIZIZZII',
#  'ZZZIIIZIZIZZ',
#  'ZZZIIIZIZIZI',
#  'ZZZIIIZIZIIZ',
#  'ZZZIIIZIZIII',
#  'ZZZIIIZIIZZZ',
#  'ZZZIIIZIIZZI',
#  'ZZZIIIZIIZIZ',
#  'ZZZIIIZIIZII',
#  'ZZZIIIZIIIZZ',
#  'ZZZIIIZIIIZI',
#  'ZZZIIIZIIIIZ',
#  'ZZZIIIZIIIII',
#  'ZZZIIIIZZZZZ',
#  'ZZZIIIIZZZZI',
#  'ZZZIIIIZZZIZ',
#  'ZZZIIIIZZZII',
#  'ZZZIIIIZZIZZ',
#  'ZZZIIIIZZIZI',
#  'ZZZIIIIZZIIZ',
#  'ZZZIIIIZZIII',
#  'ZZZIIIIZIZZZ',
#  'ZZZIIIIZIZZI',
#  'ZZZIIIIZIZIZ',
#  'ZZZIIIIZIZII',
#  'ZZZIIIIZIIZZ',
#  'ZZZIIIIZIIZI',
#  'ZZZIIIIZIIIZ',
#  'ZZZIIIIZIIII',
#  'ZZZIIIIIZZZZ',
#  'ZZZIIIIIZZZI',
#  'ZZZIIIIIZZIZ',
#  'ZZZIIIIIZZII',
#  'ZZZIIIIIZIZZ',
#  'ZZZIIIIIZIZI',
#  'ZZZIIIIIZIIZ',
#  'ZZZIIIIIZIII',
#  'ZZZIIIIIIZZZ',
#  'ZZZIIIIIIZZI',
#  'ZZZIIIIIIZIZ',
#  'ZZZIIIIIIZII',
#  'ZZZIIIIIIIZZ',
#  'ZZZIIIIIIIZI',
#  'ZZZIIIIIIIIZ',
#  'ZZZIIIIIIIII',
#  'ZZIZZZZZZZZZ',
#  'ZZIZZZZZZZZI',
#  'ZZIZZZZZZZIZ',
#  'ZZIZZZZZZZII',
#  'ZZIZZZZZZIZZ',
#  'ZZIZZZZZZIZI',
#  'ZZIZZZZZZIIZ',
#  'ZZIZZZZZZIII',
#  'ZZIZZZZZIZZZ',
#  'ZZIZZZZZIZZI',
#  'ZZIZZZZZIZIZ',
#  'ZZIZZZZZIZII',
#  'ZZIZZZZZIIZZ',
#  'ZZIZZZZZIIZI',
#  'ZZIZZZZZIIIZ',
#  'ZZIZZZZZIIII',
#  'ZZIZZZZIZZZZ',
#  'ZZIZZZZIZZZI',
#  'ZZIZZZZIZZIZ',
#  'ZZIZZZZIZZII',
#  'ZZIZZZZIZIZZ',
#  'ZZIZZZZIZIZI',
#  'ZZIZZZZIZIIZ',
#  'ZZIZZZZIZIII',
#  'ZZIZZZZIIZZZ',
#  'ZZIZZZZIIZZI',
#  'ZZIZZZZIIZIZ',
#  'ZZIZZZZIIZII',
#  'ZZIZZZZIIIZZ',
#  'ZZIZZZZIIIZI',
#  'ZZIZZZZIIIIZ',
#  'ZZIZZZZIIIII',
#  'ZZIZZZIZZZZZ',
#  'ZZIZZZIZZZZI',
#  'ZZIZZZIZZZIZ',
#  'ZZIZZZIZZZII',
#  'ZZIZZZIZZIZZ',
#  'ZZIZZZIZZIZI',
#  'ZZIZZZIZZIIZ',
#  'ZZIZZZIZZIII',
#  'ZZIZZZIZIZZZ',
#  'ZZIZZZIZIZZI',
#  'ZZIZZZIZIZIZ',
#  'ZZIZZZIZIZII',
#  'ZZIZZZIZIIZZ',
#  'ZZIZZZIZIIZI',
#  'ZZIZZZIZIIIZ',
#  'ZZIZZZIZIIII',
#  'ZZIZZZIIZZZZ',
#  'ZZIZZZIIZZZI',
#  'ZZIZZZIIZZIZ',
#  'ZZIZZZIIZZII',
#  'ZZIZZZIIZIZZ',
#  'ZZIZZZIIZIZI',
#  'ZZIZZZIIZIIZ',
#  'ZZIZZZIIZIII',
#  'ZZIZZZIIIZZZ',
#  'ZZIZZZIIIZZI',
#  'ZZIZZZIIIZIZ',
#  'ZZIZZZIIIZII',
#  'ZZIZZZIIIIZZ',
#  'ZZIZZZIIIIZI',
#  'ZZIZZZIIIIIZ',
#  'ZZIZZZIIIIII',
#  'ZZIZZIZZZZZZ',
#  'ZZIZZIZZZZZI',
#  'ZZIZZIZZZZIZ',
#  'ZZIZZIZZZZII',
#  'ZZIZZIZZZIZZ',
#  'ZZIZZIZZZIZI',
#  'ZZIZZIZZZIIZ',
#  'ZZIZZIZZZIII',
#  'ZZIZZIZZIZZZ',
#  'ZZIZZIZZIZZI',
#  'ZZIZZIZZIZIZ',
#  'ZZIZZIZZIZII',
#  'ZZIZZIZZIIZZ',
#  'ZZIZZIZZIIZI',
#  'ZZIZZIZZIIIZ',
#  'ZZIZZIZZIIII',
#  'ZZIZZIZIZZZZ',
#  'ZZIZZIZIZZZI',
#  'ZZIZZIZIZZIZ',
#  'ZZIZZIZIZZII',
#  'ZZIZZIZIZIZZ',
#  'ZZIZZIZIZIZI',
#  'ZZIZZIZIZIIZ',
#  'ZZIZZIZIZIII',
#  'ZZIZZIZIIZZZ',
#  'ZZIZZIZIIZZI',
#  'ZZIZZIZIIZIZ',
#  'ZZIZZIZIIZII',
#  'ZZIZZIZIIIZZ',
#  'ZZIZZIZIIIZI',
#  'ZZIZZIZIIIIZ',
#  'ZZIZZIZIIIII',
#  'ZZIZZIIZZZZZ',
#  'ZZIZZIIZZZZI',
#  'ZZIZZIIZZZIZ',
#  'ZZIZZIIZZZII',
#  'ZZIZZIIZZIZZ',
#  'ZZIZZIIZZIZI',
#  'ZZIZZIIZZIIZ',
#  'ZZIZZIIZZIII',
#  'ZZIZZIIZIZZZ',
#  'ZZIZZIIZIZZI',
#  'ZZIZZIIZIZIZ',
#  'ZZIZZIIZIZII',
#  'ZZIZZIIZIIZZ',
#  'ZZIZZIIZIIZI',
#  'ZZIZZIIZIIIZ',
#  'ZZIZZIIZIIII',
#  'ZZIZZIIIZZZZ',
#  'ZZIZZIIIZZZI',
#  'ZZIZZIIIZZIZ',
#  'ZZIZZIIIZZII',
#  'ZZIZZIIIZIZZ',
#  'ZZIZZIIIZIZI',
#  'ZZIZZIIIZIIZ',
#  'ZZIZZIIIZIII',
#  'ZZIZZIIIIZZZ',
#  'ZZIZZIIIIZZI',
#  'ZZIZZIIIIZIZ',
#  'ZZIZZIIIIZII',
#  'ZZIZZIIIIIZZ',
#  'ZZIZZIIIIIZI',
#  'ZZIZZIIIIIIZ',
#  'ZZIZZIIIIIII',
#  'ZZIZIZZZZZZZ',
#  'ZZIZIZZZZZZI',
#  'ZZIZIZZZZZIZ',
#  'ZZIZIZZZZZII',
#  'ZZIZIZZZZIZZ',
#  'ZZIZIZZZZIZI',
#  'ZZIZIZZZZIIZ',
#  'ZZIZIZZZZIII',
#  'ZZIZIZZZIZZZ',
#  'ZZIZIZZZIZZI',
#  'ZZIZIZZZIZIZ',
#  'ZZIZIZZZIZII',
#  'ZZIZIZZZIIZZ',
#  'ZZIZIZZZIIZI',
#  'ZZIZIZZZIIIZ',
#  'ZZIZIZZZIIII',
#  'ZZIZIZZIZZZZ',
#  'ZZIZIZZIZZZI',
#  'ZZIZIZZIZZIZ',
#  'ZZIZIZZIZZII',
#  'ZZIZIZZIZIZZ',
#  'ZZIZIZZIZIZI',
#  'ZZIZIZZIZIIZ',
#  'ZZIZIZZIZIII',
#  'ZZIZIZZIIZZZ',
#  'ZZIZIZZIIZZI',
#  'ZZIZIZZIIZIZ',
#  'ZZIZIZZIIZII',
#  'ZZIZIZZIIIZZ',
#  'ZZIZIZZIIIZI',
#  'ZZIZIZZIIIIZ',
#  'ZZIZIZZIIIII',
#  'ZZIZIZIZZZZZ',
#  'ZZIZIZIZZZZI',
#  'ZZIZIZIZZZIZ',
#  'ZZIZIZIZZZII',
#  'ZZIZIZIZZIZZ',
#  'ZZIZIZIZZIZI',
#  'ZZIZIZIZZIIZ',
#  'ZZIZIZIZZIII',
#  'ZZIZIZIZIZZZ',
#  'ZZIZIZIZIZZI',
#  'ZZIZIZIZIZIZ',
#  'ZZIZIZIZIZII',
#  'ZZIZIZIZIIZZ',
#  'ZZIZIZIZIIZI',
#  'ZZIZIZIZIIIZ',
#  'ZZIZIZIZIIII',
#  'ZZIZIZIIZZZZ',
#  'ZZIZIZIIZZZI',
#  'ZZIZIZIIZZIZ',
#  'ZZIZIZIIZZII',
#  'ZZIZIZIIZIZZ',
#  'ZZIZIZIIZIZI',
#  'ZZIZIZIIZIIZ',
#  'ZZIZIZIIZIII',
#  'ZZIZIZIIIZZZ',
#  'ZZIZIZIIIZZI',
#  'ZZIZIZIIIZIZ',
#  'ZZIZIZIIIZII',
#  'ZZIZIZIIIIZZ',
#  'ZZIZIZIIIIZI',
#  'ZZIZIZIIIIIZ',
#  'ZZIZIZIIIIII',
#  'ZZIZIIZZZZZZ',
#  'ZZIZIIZZZZZI',
#  'ZZIZIIZZZZIZ',
#  'ZZIZIIZZZZII',
#  'ZZIZIIZZZIZZ',
#  'ZZIZIIZZZIZI',
#  'ZZIZIIZZZIIZ',
#  'ZZIZIIZZZIII',
#  'ZZIZIIZZIZZZ',
#  'ZZIZIIZZIZZI',
#  'ZZIZIIZZIZIZ',
#  'ZZIZIIZZIZII',
#  'ZZIZIIZZIIZZ',
#  'ZZIZIIZZIIZI',
#  'ZZIZIIZZIIIZ',
#  'ZZIZIIZZIIII',
#  'ZZIZIIZIZZZZ',
#  'ZZIZIIZIZZZI',
#  'ZZIZIIZIZZIZ',
#  'ZZIZIIZIZZII',
#  'ZZIZIIZIZIZZ',
#  'ZZIZIIZIZIZI',
#  'ZZIZIIZIZIIZ',
#  'ZZIZIIZIZIII',
#  'ZZIZIIZIIZZZ',
#  'ZZIZIIZIIZZI',
#  'ZZIZIIZIIZIZ',
#  'ZZIZIIZIIZII',
#  'ZZIZIIZIIIZZ',
#  'ZZIZIIZIIIZI',
#  'ZZIZIIZIIIIZ',
#  'ZZIZIIZIIIII',
#  'ZZIZIIIZZZZZ',
#  'ZZIZIIIZZZZI',
#  'ZZIZIIIZZZIZ',
#  'ZZIZIIIZZZII',
#  'ZZIZIIIZZIZZ',
#  'ZZIZIIIZZIZI',
#  'ZZIZIIIZZIIZ',
#  'ZZIZIIIZZIII',
#  'ZZIZIIIZIZZZ',
#  'ZZIZIIIZIZZI',
#  'ZZIZIIIZIZIZ',
#  'ZZIZIIIZIZII',
#  'ZZIZIIIZIIZZ',
#  'ZZIZIIIZIIZI',
#  'ZZIZIIIZIIIZ',
#  'ZZIZIIIZIIII',
#  'ZZIZIIIIZZZZ',
#  'ZZIZIIIIZZZI',
#  'ZZIZIIIIZZIZ',
#  'ZZIZIIIIZZII',
#  'ZZIZIIIIZIZZ',
#  'ZZIZIIIIZIZI',
#  'ZZIZIIIIZIIZ',
#  'ZZIZIIIIZIII',
#  'ZZIZIIIIIZZZ',
#  'ZZIZIIIIIZZI',
#  'ZZIZIIIIIZIZ',
#  'ZZIZIIIIIZII',
#  'ZZIZIIIIIIZZ',
#  'ZZIZIIIIIIZI',
#  'ZZIZIIIIIIIZ',
#  'ZZIZIIIIIIII',
#  'ZZIIZZZZZZZZ',
#  'ZZIIZZZZZZZI',
#  'ZZIIZZZZZZIZ',
#  'ZZIIZZZZZZII',
#  'ZZIIZZZZZIZZ',
#  'ZZIIZZZZZIZI',
#  'ZZIIZZZZZIIZ',
#  'ZZIIZZZZZIII',
#  'ZZIIZZZZIZZZ',
#  'ZZIIZZZZIZZI',
#  'ZZIIZZZZIZIZ',
#  'ZZIIZZZZIZII',
#  'ZZIIZZZZIIZZ',
#  'ZZIIZZZZIIZI',
#  'ZZIIZZZZIIIZ',
#  'ZZIIZZZZIIII',
#  'ZZIIZZZIZZZZ',
#  'ZZIIZZZIZZZI',
#  'ZZIIZZZIZZIZ',
#  'ZZIIZZZIZZII',
#  'ZZIIZZZIZIZZ',
#  'ZZIIZZZIZIZI',
#  'ZZIIZZZIZIIZ',
#  'ZZIIZZZIZIII',
#  'ZZIIZZZIIZZZ',
#  'ZZIIZZZIIZZI',
#  'ZZIIZZZIIZIZ',
#  'ZZIIZZZIIZII',
#  'ZZIIZZZIIIZZ',
#  'ZZIIZZZIIIZI',
#  'ZZIIZZZIIIIZ',
#  'ZZIIZZZIIIII',
#  'ZZIIZZIZZZZZ',
#  'ZZIIZZIZZZZI',
#  'ZZIIZZIZZZIZ',
#  'ZZIIZZIZZZII',
#  'ZZIIZZIZZIZZ',
#  'ZZIIZZIZZIZI',
#  'ZZIIZZIZZIIZ',
#  'ZZIIZZIZZIII',
#  'ZZIIZZIZIZZZ',
#  'ZZIIZZIZIZZI',
#  'ZZIIZZIZIZIZ',
#  'ZZIIZZIZIZII',
#  'ZZIIZZIZIIZZ',
#  'ZZIIZZIZIIZI',
#  'ZZIIZZIZIIIZ',
#  'ZZIIZZIZIIII',
#  'ZZIIZZIIZZZZ',
#  'ZZIIZZIIZZZI',
#  'ZZIIZZIIZZIZ',
#  'ZZIIZZIIZZII',
#  'ZZIIZZIIZIZZ',
#  'ZZIIZZIIZIZI',
#  'ZZIIZZIIZIIZ',
#  'ZZIIZZIIZIII',
#  'ZZIIZZIIIZZZ',
#  'ZZIIZZIIIZZI',
#  'ZZIIZZIIIZIZ',
#  'ZZIIZZIIIZII',
#  'ZZIIZZIIIIZZ',
#  'ZZIIZZIIIIZI',
#  'ZZIIZZIIIIIZ',
#  'ZZIIZZIIIIII',
#  'ZZIIZIZZZZZZ',
#  'ZZIIZIZZZZZI',
#  'ZZIIZIZZZZIZ',
#  'ZZIIZIZZZZII',
#  'ZZIIZIZZZIZZ',
#  'ZZIIZIZZZIZI',
#  'ZZIIZIZZZIIZ',
#  'ZZIIZIZZZIII',
#  'ZZIIZIZZIZZZ',
#  'ZZIIZIZZIZZI',
#  'ZZIIZIZZIZIZ',
#  'ZZIIZIZZIZII',
#  'ZZIIZIZZIIZZ',
#  'ZZIIZIZZIIZI',
#  'ZZIIZIZZIIIZ',
#  'ZZIIZIZZIIII',
#  'ZZIIZIZIZZZZ',
#  'ZZIIZIZIZZZI',
#  'ZZIIZIZIZZIZ',
#  'ZZIIZIZIZZII',
#  'ZZIIZIZIZIZZ',
#  'ZZIIZIZIZIZI',
#  'ZZIIZIZIZIIZ',
#  'ZZIIZIZIZIII',
#  'ZZIIZIZIIZZZ',
#  'ZZIIZIZIIZZI',
#  'ZZIIZIZIIZIZ',
#  'ZZIIZIZIIZII',
#  'ZZIIZIZIIIZZ',
#  'ZZIIZIZIIIZI',
#  'ZZIIZIZIIIIZ',
#  'ZZIIZIZIIIII',
#  'ZZIIZIIZZZZZ',
#  'ZZIIZIIZZZZI',
#  'ZZIIZIIZZZIZ',
#  'ZZIIZIIZZZII',
#  'ZZIIZIIZZIZZ',
#  'ZZIIZIIZZIZI',
#  'ZZIIZIIZZIIZ',
#  'ZZIIZIIZZIII',
#  'ZZIIZIIZIZZZ',
#  'ZZIIZIIZIZZI',
#  'ZZIIZIIZIZIZ',
#  'ZZIIZIIZIZII',
#  'ZZIIZIIZIIZZ',
#  'ZZIIZIIZIIZI',
#  'ZZIIZIIZIIIZ',
#  'ZZIIZIIZIIII',
#  'ZZIIZIIIZZZZ',
#  'ZZIIZIIIZZZI',
#  'ZZIIZIIIZZIZ',
#  'ZZIIZIIIZZII',
#  'ZZIIZIIIZIZZ',
#  'ZZIIZIIIZIZI',
#  'ZZIIZIIIZIIZ',
#  'ZZIIZIIIZIII',
#  'ZZIIZIIIIZZZ',
#  'ZZIIZIIIIZZI',
#  'ZZIIZIIIIZIZ',
#  'ZZIIZIIIIZII',
#  'ZZIIZIIIIIZZ',
#  'ZZIIZIIIIIZI',
#  'ZZIIZIIIIIIZ',
#  'ZZIIZIIIIIII',
#  'ZZIIIZZZZZZZ',
#  'ZZIIIZZZZZZI',
#  'ZZIIIZZZZZIZ',
#  'ZZIIIZZZZZII',
#  'ZZIIIZZZZIZZ',
#  'ZZIIIZZZZIZI',
#  'ZZIIIZZZZIIZ',
#  'ZZIIIZZZZIII',
#  'ZZIIIZZZIZZZ',
#  'ZZIIIZZZIZZI',
#  'ZZIIIZZZIZIZ',
#  'ZZIIIZZZIZII',
#  'ZZIIIZZZIIZZ',
#  'ZZIIIZZZIIZI',
#  'ZZIIIZZZIIIZ',
#  'ZZIIIZZZIIII',
#  'ZZIIIZZIZZZZ',
#  'ZZIIIZZIZZZI',
#  'ZZIIIZZIZZIZ',
#  'ZZIIIZZIZZII',
#  'ZZIIIZZIZIZZ',
#  'ZZIIIZZIZIZI',
#  'ZZIIIZZIZIIZ',
#  'ZZIIIZZIZIII',
#  'ZZIIIZZIIZZZ',
#  'ZZIIIZZIIZZI',
#  'ZZIIIZZIIZIZ',
#  'ZZIIIZZIIZII',
#  'ZZIIIZZIIIZZ',
#  'ZZIIIZZIIIZI',
#  'ZZIIIZZIIIIZ',
#  'ZZIIIZZIIIII',
#  'ZZIIIZIZZZZZ',
#  'ZZIIIZIZZZZI',
#  'ZZIIIZIZZZIZ',
#  'ZZIIIZIZZZII',
#  'ZZIIIZIZZIZZ',
#  'ZZIIIZIZZIZI',
#  'ZZIIIZIZZIIZ',
#  'ZZIIIZIZZIII',
#  'ZZIIIZIZIZZZ',
#  'ZZIIIZIZIZZI',
#  'ZZIIIZIZIZIZ',
#  'ZZIIIZIZIZII',
#  'ZZIIIZIZIIZZ',
#  'ZZIIIZIZIIZI',
#  'ZZIIIZIZIIIZ',
#  'ZZIIIZIZIIII',
#  'ZZIIIZIIZZZZ',
#  'ZZIIIZIIZZZI',
#  'ZZIIIZIIZZIZ',
#  'ZZIIIZIIZZII',
#  'ZZIIIZIIZIZZ',
#  'ZZIIIZIIZIZI',
#  'ZZIIIZIIZIIZ',
#  'ZZIIIZIIZIII',
#  'ZZIIIZIIIZZZ',
#  'ZZIIIZIIIZZI',
#  'ZZIIIZIIIZIZ',
#  'ZZIIIZIIIZII',
#  'ZZIIIZIIIIZZ',
#  'ZZIIIZIIIIZI',
#  'ZZIIIZIIIIIZ',
#  'ZZIIIZIIIIII',
#  'ZZIIIIZZZZZZ',
#  'ZZIIIIZZZZZI',
#  'ZZIIIIZZZZIZ',
#  'ZZIIIIZZZZII',
#  'ZZIIIIZZZIZZ',
#  'ZZIIIIZZZIZI',
#  'ZZIIIIZZZIIZ',
#  'ZZIIIIZZZIII',
#  'ZZIIIIZZIZZZ',
#  'ZZIIIIZZIZZI',
#  'ZZIIIIZZIZIZ',
#  'ZZIIIIZZIZII',
#  'ZZIIIIZZIIZZ',
#  'ZZIIIIZZIIZI',
#  'ZZIIIIZZIIIZ',
#  'ZZIIIIZZIIII',
#  'ZZIIIIZIZZZZ',
#  'ZZIIIIZIZZZI',
#  'ZZIIIIZIZZIZ',
#  'ZZIIIIZIZZII',
#  'ZZIIIIZIZIZZ',
#  'ZZIIIIZIZIZI',
#  'ZZIIIIZIZIIZ',
#  'ZZIIIIZIZIII',
#  'ZZIIIIZIIZZZ',
#  'ZZIIIIZIIZZI',
#  'ZZIIIIZIIZIZ',
#  'ZZIIIIZIIZII',
#  'ZZIIIIZIIIZZ',
#  'ZZIIIIZIIIZI',
#  'ZZIIIIZIIIIZ',
#  'ZZIIIIZIIIII',
#  'ZZIIIIIZZZZZ',
#  'ZZIIIIIZZZZI',
#  'ZZIIIIIZZZIZ',
#  'ZZIIIIIZZZII',
#  'ZZIIIIIZZIZZ',
#  'ZZIIIIIZZIZI',
#  'ZZIIIIIZZIIZ',
#  'ZZIIIIIZZIII',
#  ...]

# %%
print(len(all_other_z_paulis))
# Out:
# 4059

# %%
for p in tqdm(all_other_z_paulis):
    if not np.isclose(np.trace(mat @ Pauli(p)), 0):
        print(p, np.real_if_close(np.trace(mat @ Pauli(p))))

# %%
def worker(p):
    """
    Process a single Pauli string 'p'. Compute the trace of (mat @ Pauli(p))
    and return (p, trace_value) if the trace is not close to zero.
    Otherwise, return None.
    """
    # Construct the Pauli matrix from the string.
    pauli_matrix = Pauli(p)
    trace_val = np.trace(mat @ pauli_matrix)
    
    if not np.isclose(trace_val, 0):
        # np.real_if_close returns a real number if the result is close to real.
        return (p, np.real_if_close(trace_val))
    return None

# %%
import multiprocessing as mp
with mp.Pool() as pool:
    # Use imap_unordered for parallel mapping; tqdm displays a progress bar.
    for result in tqdm(pool.imap_unordered(worker, all_other_z_paulis),
                        total=len(all_other_z_paulis)):
        if result is not None:
            p_string, trace_value = result
            print(p_string, trace_value)
# Out:
#  76%|███████▌  | 3079/4059 [00:43<00:13, 74.73it/s]
# IZIIIIIIIIII -2047.9999999999982
#  94%|█████████▍| 3822/4059 [00:53<00:03, 78.36it/s]
# IIIZIIIIIIII -2048.000000000001
#  99%|█████████▉| 4026/4059 [00:55<00:00, 118.70it/s]
# IIIIIZIIIIII -2047.999999999999
# IIIIIIIIIZII -2047.9999999999995
# 100%|██████████| 4059/4059 [00:56<00:00, 72.39it/s]
# IIIIIIIZIIII -2047.9999999999995
# IIIIIIIIIIIZ -2048.0
